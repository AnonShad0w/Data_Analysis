# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv("Facebook_Salaries_2018.csv")
df1.head(5)
# Out:
#                            Job_Role     Pay       Location State Submit_Date  \
# 0   VIDEO PRODUCT MARKETING MANAGER  125400  MENLO PARK CA    CA   2/19/2018
# 1            ACCESS MANAGEMENT LEAD  114642      AUSTIN TX    TX    3/2/2018
# 2           ADS PRODUCT MEASUREMENT  148000  MENLO PARK CA    CA   8/30/2018
# 3         ADS PRODUCT STRATEGY LEAD  195000  MENLO PARK CA    CA   2/14/2018
# 4         ADS PRODUCT STRATEGY LEAD  195000  MENLO PARK CA    CA    2/5/2018
#
#    Submit_Date_Mo  Submit_Date_Yr  Hire_Date  Hire_Date_Mo  Hire_Date_Yr
# 0               2            2018  8/15/2018             8          2018
# 1               3            2018  8/28/2018             8          2018
# 2               8            2018  9/10/2018             9          2018
# 3               2            2018  2/26/2018             2          2018
# 4               2            2018   8/1/2018             8          2018

# %%
df1['Salary'].hist(bins=50)

# %%
df2=df1.set_index("City")

# %%
df2

# %%
mpdf=df2.loc['SEATTLE CA']

# %%
mpdf

# %%
mpdf.plot.bar()

# %%
df3=df1.set_index("Job_Role")

# %%
df3.head()
# Out:
#                                      Pay       Location State Submit_Date  \
# Job_Role
#  VIDEO PRODUCT MARKETING MANAGER  125400  MENLO PARK CA    CA   2/19/2018
# ACCESS MANAGEMENT LEAD            114642      AUSTIN TX    TX    3/2/2018
# ADS PRODUCT MEASUREMENT           148000  MENLO PARK CA    CA   8/30/2018
# ADS PRODUCT STRATEGY LEAD         195000  MENLO PARK CA    CA   2/14/2018
# ADS PRODUCT STRATEGY LEAD         195000  MENLO PARK CA    CA    2/5/2018
#
#                                   Submit_Date_Mo  Submit_Date_Yr  Hire_Date  \
# Job_Role
#  VIDEO PRODUCT MARKETING MANAGER               2            2018  8/15/2018
# ACCESS MANAGEMENT LEAD                         3            2018  8/28/2018
# ADS PRODUCT MEASUREMENT                        8            2018  9/10/2018
# ADS PRODUCT STRATEGY LEAD                      2            2018  2/26/2018
# ADS PRODUCT STRATEGY LEAD                      2            2018   8/1/2018
#
# ...

# %%
df3.loc['DATA SCIENTIST']
# Out:
#                    Pay          Location State Submit_Date  Submit_Date_Mo  \
# Job_Role
# DATA SCIENTIST   90000     MENLO PARK CA    CA    2/7/2018               2
# DATA SCIENTIST  100000     MENLO PARK CA    CA   3/16/2018               3
# DATA SCIENTIST  100000     MENLO PARK CA    CA    3/6/2018               3
# DATA SCIENTIST  100000     MENLO PARK CA    CA    2/8/2018               2
# DATA SCIENTIST  105000     MENLO PARK CA    CA  11/14/2018              11
# DATA SCIENTIST  105000     MENLO PARK CA    CA  11/16/2018              11
# DATA SCIENTIST  105000     MENLO PARK CA    CA  11/16/2018              11
# DATA SCIENTIST  115000     MENLO PARK CA    CA   11/1/2018              11
# DATA SCIENTIST  115000     MENLO PARK CA    CA   11/2/2018              11
# DATA SCIENTIST  115000     MENLO PARK CA    CA   3/20/2018               3
# DATA SCIENTIST  115000     MENLO PARK CA    CA   3/26/2018               3
# ...

# %%
plt.figure(figsize=(12,6))
ax = sns.boxplot(x="State", y="Pay", data=df1,palette='rainbow')

ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
ax.set_title("State vs Salary for Facebook")
